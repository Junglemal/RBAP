# %%
import pandas as pd

# %% [markdown]
# Результаты саммаризации

# %%
gemma4b_results = pd.read_csv('D:/pars/baseline_dataset_with_gemma4b.csv')
gemma4b_results
# Out:
#                                   Текст отзыва (API)  \
# 0  14.11.2025 пришли в банк Дом РФ-одобрили ипоте...
# 1  13.11.25 обратилась в офис банка в городк Тюме...
# 2  Обратился в отделение банка 13 ноября этого го...
# 3  Сегодня в 16:30 пришла в банк Дом Рф в городе ...
# 4  13.11.2025 года посетила офис Банка Дом Рф в г...
# 5  Сегодня утром пришел в офис банка города Тюмен...
# 6  Здравствуйте. При попытке оплатить ежемесячный...
# 7  Оформляли ипотеку в офисе банка дом ой  12.11....
# 8  11.11.2025 Я обратилась в Абсолют банк в Челяб...
# 9  Сегодня пришел в офис банка дом рф, буду оформ...
#
#                                 gemma4b полный ответ  \
# 0  Отлично! Вот структурированное изложение произ...
# 1  Это довольно детальное описание вашего опыта с...
# 2  Вот более структурированный вариант вашего отз...
# 3  Это замечательный отзыв! Он четко и конкретно ...
# 4  Вот несколько вариантов, как можно перефразиро...
# 5  Отлично! Звучит как очень продуктивная и опера...
# ...

# %% [markdown]
# Работа Gemma3:27b LLM-as-a-Judge

# %%
judge_results = pd.read_csv('D:/pars/evaluation_results.csv')
judge_results
# Out:
#    index  original_text_length  \
# 0      0                   359
# 1      1                   412
# 2      2                   469
# 3      3                   546
# 4      4                   369
# 5      5                   409
# 6      6                  1176
# 7      7                   345
# 8      8                   303
# 9      9                   509
#
#                                         summary_text  summary_length_words  \
# 0  Клиент положительно оценил быстрое и удобное о...                    20
# 1  Клиент остался доволен быстрой и профессиональ...                    19
# 2  Клиент остался доволен быстрой оформкой карты ...                    18
# 3  Клиент высоко оценил быстрое, профессиональное...                    19
# 4  Клиент высоко оценил быстрое и профессионально...                    20
# 5  Клиент оценил быстрое и эффективное прохождени...                    17
# 6  Клиент обнаружил неверную отображаемую процент...                    24
# ...

# %% [markdown]
# Генерация обзорного отчёта результатов работы судьи

# %%
file_path = "D:/pars/evaluation_report.txt"

with open(file_path, "r", encoding="utf-8") as file:
    content = file.read()

print(content)
# Out:
# ...
# ОТЧЕТ ПО ОЦЕНКЕ КАЧЕСТВА СУММАРИЗАЦИИ
# ...
#
# 📊 ОБЩАЯ СТАТИСТИКА (10 отзывов):
# ----------------------------------------
#
# Релевантность:
#   Среднее: 4.10/5
#   Медиана: 4.00/5
#   Std: 0.57
#   Диапазон: 3.00 - 5.00
#
# Краткость:
#   Среднее: 4.50/5
#   Медиана: 4.50/5
#   Std: 0.53
#   Диапазон: 4.00 - 5.00
#
# Ясность:
#   Среднее: 4.90/5
#   Медиана: 5.00/5
#   Std: 0.32
#   Диапазон: 4.00 - 5.00
#
# Общая оценка:
#   Среднее: 4.50/5
#   Медиана: 4.33/5
#   Std: 0.33
#   Диапазон: 4.00 - 5.00
#
# 📈 РАСПРЕДЕЛЕНИЕ ПО КАТЕГОРИЯМ КАЧЕСТВА:
# ----------------------------------------
#   Отлично (4.5-5.0): 4 отзывов (40.0%)
#   Хорошо (4.0-4.5): 6 отзывов (60.0%)
#
# 🏆 ЛУЧШИЕ СУММАРИЗАЦИИ (Топ-3):
# ----------------------------------------
#
# 1. Оценка: 5.00/5
#    Суммаризация: Клиент высоко оценил быстрое и профессиональное обслуживание менеджера Дмитрия при переоформлении ипотечного кредита в филиале Банка Дом РФ в Ижевске....
#    Длина: 20 слов
#
# 2. Оценка: 5.00/5
# ...
